# %% [markdown]
# # 🛍️ Olist E-Commerce Analytics
# ### End-to-End Data Science Project | Marketing · Logistics · NLP

# %% [markdown]
# ## Data Ingestion

# %%
# Data Manipulation and visualization
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# Sklearn library
from sklearn.metrics import silhouette_score, classification_report
from sklearn.cluster import KMeans

# Hugging Face
from transformers import pipeline

# Logger
from src.utils.logging import setup_logging
setup_logging()

# %%
# Importing sqlite engine and tables defined in ingest module.
from src.data.ingest import engine

tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", engine)

table_dict = {}
# Loop through all tables from SQLite

for table in sorted(tables["name"]):
    query_df = pd.read_sql(f"SELECT * from {table}",engine)
    print('=='*35)
    print(f"Table: {table}")
    print('=='*35)
    display(query_df.head(2))
    table_dict[table] = query_df 
    print(f"Loaded: {query_df.shape[0]:,} rows, {query_df.shape[1]} columns")
# Out:
# ...
# Table: customers
# ...
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# Loaded: 99,441 rows, 5 columns
# ...
# Table: geolocation
# ...
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# Loaded: 1,000,163 rows, 5 columns
# ...
# Table: order_items
# ...
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# ...

# %% [markdown]
# | Table | Purpose | Join Key |
# |-------|---------|----------|
# | `orders` | Order information | `order_id` (Primary Key) |
# | `customers` | Customer demographics | `customer_id` → `orders.customer_id` ,`customer_unique_id` (Unique Key)|
# | `order_items` | Individual items per order | `order_id` → `orders.order_id` |
# | `products` | Product details | `product_id` → `order_items.product_id` |
# | `sellers` | Seller information | `seller_id` → `order_items.seller_id` |
# | `order_payments` | Payment methods | `order_id` → `orders.order_id` |
# | `order_reviews` | Customer reviews | `order_id` → `orders.order_id` |
# | `product_category_name_translation` | Category translations | `product_category_name` → `products.product_category_name` |
# | `geolocation` | Zip code to lat/long | `zip_code_prefix` → `customers.customer_zip_code_prefix` |

# %% [markdown]
# ## Bronze Layer

# %%
print("=="*55)
print("Schema Validation")
print("=="*55)

# Orders & Items
print(f"1.  Orders:                          {table_dict['orders']['order_id'].nunique():,}")
print(f"2.  Items sold:                      {len(table_dict['order_items']):,} (avg {len(table_dict['order_items'])/table_dict['orders']['order_id'].nunique():.2f} per order)")
print(f"3.  Orders without items:            {(~table_dict['orders']['order_id'].isin(table_dict['order_items']['order_id'])).sum()}")

# Customers & Sellers
print(f"4.  Each order have valid customer?: {table_dict["orders"]['customer_id'].isin(table_dict["customers"]['customer_id']).all()}")

print(f"5.  Confirmed delivered rate:        {table_dict["orders"]["order_delivered_customer_date"].notna().mean():.0%}")

check_1 = table_dict["order_items"].groupby("order_id")[['product_id','seller_id']].nunique()
print(f"6.  Orders with multiple products:   {(check_1['product_id']>1).sum():,}")
print(f"7.  Orders with multiple sellers:    {(check_1['seller_id'] > 1).sum():,}")

# Order_payments
check_2 = table_dict["order_payments"].groupby('order_id')['payment_type'].nunique()
print(f"8.  Orders with multiple payments:   {(check_2 > 1).sum():,}")

# Categories
missing_translation = (table_dict["products"][~table_dict["products"]["product_category_name"].\
                                              isin(table_dict["product_category_name_translation"]["product_category_name"])]["product_category_name"].unique()).tolist()
print(f"9.  Categories without translation:  {missing_translation}")

# Reviews
print(f"10. Valid review comment rate :      {table_dict["order_reviews"]["review_comment_message"].notna().mean():.0%}")
# Out:
# ...
# Schema Validation
# ...
# 1.  Orders:                          99,441
# 2.  Items sold:                      112,650 (avg 1.13 per order)
# 3.  Orders without items:            775
# 4.  Each order have valid customer?: True
# 5.  Confirmed delivered rate:        97%
# 6.  Orders with multiple products:   3,236
# 7.  Orders with multiple sellers:    1,278
# 8.  Orders with multiple payments:   2,246
# 9.  Categories without translation:  [nan, 'pc_gamer', 'portateis_cozinha_e_preparadores_de_alimentos']
# 10. Valid review comment rate :      41%

# %% [markdown]
# ## Silver Layer

# %%
from src.data.builder import _build_master_dataframe

master_df  = _build_master_dataframe(engine)
print(f"✅ Master DataFrame Created: {master_df.shape}")
# Out:
# ✅ Master DataFrame Created: (119143, 24)

# %%
print("=="*30)
print("Aggregation required per order_id")
print("=="*30)
dedup_dict = {}
for col in master_df:
    if col not in ['order_id','order_item_id'] and (master_df.groupby('order_id')[col].nunique()>1).any():
        dedup_dict[col] = master_df[col].dtype
        print(f'Need aggregation: {col}, {master_df[col].dtype}')
# Out:
# ...
# Aggregation required per order_id
# ...
# Need aggregation: price, float64
# Need aggregation: freight_value, float64
# Need aggregation: seller_id, str
# Need aggregation: product_id, str
# Need aggregation: product_category, str
# Need aggregation: seller_state, str
# Need aggregation: seller_city, str
# Need aggregation: seller_zip_code_prefix, float64
# Need aggregation: payment_type, str
# Need aggregation: payment_value, float64
# Need aggregation: review_score, float64
# Need aggregation: review_comment_message, str

# %% [markdown]
# ### Key Assumptions & Decisions
#
# - Analysis limited to **delivered orders only** (97% of all orders).
#
# - Aggregation at `order_id` level (before dedup):
#   - `sum` : `price`, `freight_value`, `payment_value`
#   - `mean` : `review_score`
#   - `first non-null` : `review_comment_message`, `product_id`, `seller_id`, `seller_zip_code_prefix`
#   - `mode` : `product_category`, `seller_state`, `seller_city`, `payment_type`.
#
# - Geolocation added via ZIP prefix — customer and seller lat/long merged from aggregated geolocation table (mean lat/long per ZIP)
#
# - 6 orders flagged as `canceled` but have delivery date — retained under logistics scope.
#
# - 3 categories missing English translation — Portuguese used as fallback.
#
# - `nlp_df` derived from `logistics_df` — inherits all logistics features.

# %% [markdown]
# # Gold Layer

# %%
from src.data.builder import build_logistics_dataframe
from src.utils.validation import validate_dataframe

# logistics DataFrame
logistics_df = build_logistics_dataframe(engine)
print(f"✅ Logistics DataFrame: {logistics_df.shape} | Late: {logistics_df['is_late'].mean()*100:.1f}% | Interstate: {logistics_df['is_interstate'].mean()*100:.1f}%")
# Validation 
validate_dataframe(logistics_df)
# Out:
# ✅ Logistics DataFrame: (96476, 31) | Late: 8.1% | Interstate: 64.1%
# ...
# Null & Duplicate Validation
# ...
# ✅ No duplicates
#
# Missing value:
# order_approved_at                  14
# order_delivered_carrier_date        1
# payment_type                        1
# review_comment_message          57513
# mean_review_score                 646
# vendor_handling_days                1
# carrier_transit_days                1
# cust_latitude                     264
# cust_longitude                    264
# seller_latitude                   215
# seller_longitude                  215
# dtype: int64

# %% [markdown]
# ## Module 1 — Marketing & Customer Segmentation

# %% [markdown]
# ### 1.1 Business Performance — Time Series

# %%
from src.visualization.business import plot_monthly_performance_dashboard

# Visualize monthly business performance and logistics KPIs
plot_monthly_performance_dashboard(logistics_df)

# %% [markdown]
# - Revenue and orders peak in Nov 2017 during Black Friday — clear seasonality.
# - Delivery days improved from 50+ days in 2016 to below 10 days by 2017 — rapid operational maturity.
# - Late rate spikes during peak seasons like Nov 2017 — suggesting carrier capacity constraints during high demand.
# - Top 5 categories drive ~40% of total revenue, with computers & accessories leading.
# - Review score stabilised around 4.1–4.3 as operations matured.

# %% [markdown]
# ### 1.2 RFM Segmentation with KMeans

# %%
from src.analytics.rfm import build_customer_segmentation

# Build customer segments using RFM and KMeans
logistics_df, rfm, X_train_scaled, X_test_scaled, kmeans = build_customer_segmentation(logistics_df)

# Descriptive summary
print("=="*20)
print("Base RFM Metrics Summary")
print("=="*20)
print(rfm[['recency','frequency','monetary']].describe().round(2))
# Out:
# ...
# Base RFM Metrics Summary
# ...
#         recency  frequency  monetary
# count  93356.00   93356.00  93356.00
# mean     237.97       1.03    148.63
# std      152.62       0.21    245.41
# min        1.00       1.00      0.85
# 25%      114.00       1.00     48.90
# 50%      219.00       1.00     89.90
# 75%      346.00       1.00    159.90
# max      714.00      15.00  13440.00

# %%
# Evaluate candidate values of k using Elbow and Silhouette methods
inertia = []
silhouette =[]
for cluster in range(2,12): # Silhouette need at least two cluster.
    kmeans = KMeans(n_clusters = cluster,random_state = 42)
    kmeans.fit(X_train_scaled) 

    # Within-cluster sum of squares (Elbow)
    inertia.append(kmeans.inertia_)

    # Evaluate clustering on the held-out test set
    test_label = kmeans.predict(X_test_scaled) # Predicted lables
    silhouette.append(silhouette_score(X_test_scaled,test_label)) 

# Plot cluster validation metrics
fig,axis = plt.subplots(1,2,figsize=(10,5),sharex=True)

# Elbow Curve
axis[0].plot(range(2,12),inertia,marker='D',color='teal')
axis[0].set_xlabel("Number of Clusters (k)")
axis[0].set_ylabel("Inertia")
axis[0].set_title("Elbow Curve")
axis[0].set_xticks(range(2,12))
axis[0].axvline(x=4,color='r',linestyle='--',alpha=0.5,label="Tight Cluster, k = 4")
axis[0].legend()
axis[0].grid(alpha=0.3)

# Silhouette Score
axis[1].plot(range(2,12),silhouette,marker='D',color='blue')
axis[1].set_xticks(range(2,12))
axis[1].axvline(x=4,color='r',linestyle='--',alpha=0.5,label="Well Seperated Cluster, k = 4")
axis[1].legend()
axis[1].grid(alpha=0.3)
axis[1].set_title("Silhouette Score")
axis[1].set_xlabel("Number of Clusters (k)")
axis[1].set_ylabel("Silhouette")
plt.suptitle("RFM Cluster Validation", fontsize=11, fontweight='bold')
plt.tight_layout()
plt.savefig('../outputs/elbow_silhouette_validation.png')
plt.show()

# %% [markdown]
# - The elbow curve shows inertia dropping sharply up to k=4, then flattens significantly while the silhouette score reaches peak of 0.365. Therefore, choosing the optimal cluster, k=4, balances the tight cluster with inter-cluster separation to avoid overfitting risk of higher clusters.

# %%
# Average RFM metrics by cluster to interpret and assign business segment names
print(round(rfm.groupby('KMeans_Segment')[['recency','frequency','monetary']].mean()).astype(int))

# Visualize the customer segments using RFM metrics
from src.visualization.rfm import plot_rfm_segments
plot_rfm_segments(rfm)
# Out:
#                 recency  frequency  monetary
# KMeans_Segment
# 0                   428          1       112
# 1                   165          1       269
# 2                   220          2       292
# 3                   153          1        47

# %% [markdown]
# - Segment 2 customers drive the highest value, need loyalty discounts.
#
# - Segmnent 1 customers represent high-spend one-time buyers, need re-engagement before they become Lost.

# %% [markdown]
# ### Module 2 — Logistics & Delivery Performance

# %% [markdown]
# ### 2.1 Correlation heatmap

# %%
from src.visualization.logistics import plot_logistics_correlation

# Visualize Spearman correlations among key logistics drivers
plot_logistics_correlation(logistics_df)

# %% [markdown]
# - **Carrier transit** drives late delivery (0.35) — not vendor handling (0.14) or distance (0.06).
# - **Late delivery** reduces satisfaction (-0.29) — customers penalise delays.
# - **Distance** correlates with freight (r=0.56) and interstate (r=0.76) — longer routes = higher cost.
#
# - ** Summary** distance → carrier transit → late delivery → bad review.

# %% [markdown]
# ### 2.2 Delivery Bottleneck & Distance

# %%
from src.visualization.logistics import plot_logistics_bottlenecks

# Visualize key logistics bottlenecks
plot_logistics_bottlenecks(logistics_df)

# %% [markdown]
# - Carrier transit (9 days) is **3x longer** than vendor handling (2.7 days) — bottleneck is the carrier, not the seller.
# - Freight cost shows no clear linear relationship with distance — flat-rate pricing confirmed.

# %% [markdown]
# ### 2.3 SLA Breach Rate

# %% [markdown]
# SLA Breach Rate
# - **H₀:** SLA breach rate is uniform across all Brazilian states
# - **H₁:** SLA breach rate varies significantly across states
# - Alpha = 0.05

# %%
# Run Chi-square analysis of SLA breach rates by customer state
from src.analytics.statistics import analyze_sla_by_state
contingency, chi2, p, dof, expected = analyze_sla_by_state(logistics_df)

# Visualize state-level SLA breach rates against the national benchmark
from src.visualization.logistics import plot_sla_breach_by_state
plot_sla_breach_by_state(logistics_df, contingency, chi2, p, dof)
# Out:
# 2026-08-09 04:44:52,578 src.analytics.statistics INFO: Chi2: 1622.01, p-value: 0.00e+00, alpha: 0.05
# 2026-08-09 04:44:52,579 src.analytics.statistics INFO: SLA breach rate varies significantly across states

# %% [markdown]
# - Chi-square analysis (χ² = 1622.01, p < 0.001) confirms that SLA breach rates vary significantly across Brazilian states.
# - Combined with the correlation findings — carrier transit drives late deliveries (0.35), and vendor handling has minimal impact (0.14) indicates regional carrier optimization should be the top logistics priority.

# %% [markdown]
# ## Module 3 — Sentiment & Text Analysis

# %% [markdown]
# ### 3.1 TF-IDF Vectorizer

# %%
from src.nlp.sentiment import _tfidf_vectorizer, build_sentiment_analysis
from src.visualization.nlp import plot_nlp_dashboard

# Build NLP dataset and TF-IDF features
nlp_df, word_frequency_sorted, X_sparse, vectorizer = build_sentiment_analysis(logistics_df)

# Validation 
print(f"✅ NLP DataFrame:      {nlp_df.shape} | Avg score: {nlp_df['mean_review_score'].mean():.2f}")
validate_dataframe(nlp_df)
print(f"TF-IDF Matrix Shape: {X_sparse.shape}")

# Visualize 
# The TF-IDF helper is passed to generate word frequencies for late and on-time review comparisons.
plot_nlp_dashboard(nlp_df, _tfidf_vectorizer)
# Out:
# ✅ NLP DataFrame:      (38963, 33) | Avg score: 3.77
# ...
# Null & Duplicate Validation
# ...
# ✅ No duplicates
#
# Missing value:
# order_approved_at      7
# payment_type           1
# cust_latitude        101
# cust_longitude       101
# seller_latitude       83
# seller_longitude      83
# dtype: int64
# TF-IDF Matrix Shape: (38963, 8847)

# %% [markdown]
# - Late orders have significantly lower review score than on-time orders.
# - Customers write longer review when they have bad experience.(i.e., 100 length for 1 star review).
# - Review score does not have much variation across customer segmentation, interstate flag so `is_interstate` and `customer_segment` excluded in sentiment anlysis.
# - Classifying review scores based for sentiment analysis model based on rule:
#   - 4-5 stars → **Positive** (67.4%)
#   - 3 stars → **Neutral** (8.9%)
#   - 1-2 stars → **Negative** (23.7%)

# %% [markdown]
# ### 3.3 Score-Based Sentiment Analysis

# %%
from src.visualization.nlp import plot_sentiment_correlation

# Visualize relationships between logistics drivers and sentiment
plot_sentiment_correlation(nlp_df)

# %% [markdown]
# - **Final features:** `review_length` (-0.33), `is_late` (-0.34), `delivery_days` (-0.27) have the strongest correlation with `mean_review_score`.
#
# - **Multicollinearity check:** `delivery_days` has strong correlation with `carrier_transit_days` (0.88) and `vendor_handling_days` (0.43). Dropped individual legs to avoid multicollinearity, leaving `delivery_days`.
#
# - **Text features:** TF-IDF vectorization on `review_comment_message` (Portuguese, RSLPStemmer, stopwords removed).

# %%
# Distribution Check 
nlp_df[['is_late','review_length','delivery_days']].describe()
# Out:
#             is_late  review_length  delivery_days
# count  38963.000000   38963.000000   38963.000000
# mean       0.109386      67.416087      13.024639
# std        0.312127      53.187215      10.819290
# min        0.000000       1.000000       0.000000
# 25%        0.000000      28.000000       6.000000
# 50%        0.000000      52.000000      10.000000
# 75%        0.000000      92.000000      16.000000
# max        1.000000     208.000000     195.000000

# %% [markdown]
# - Robust Scaler needed for extreme outliers in review_length, delivery_days.

# %%
# Prepare sentiment labels from review scores
from src.models.sentiment_model import label_sentiment, train_sentiment_model
nlp_df = label_sentiment(nlp_df)

# Train the Logistic Regression sentiment classification model
model, X_test, y_pred, y_test = train_sentiment_model(nlp_df,X_sparse, max_iter = 120, regularization = 0.1)

# Report model convergence and classification performance
print(f'Number of Iteration used: {model.named_steps['logistic'].n_iter_[0]}\n')
print(classification_report(y_test,y_pred))
# Out:
# Number of Iteration used: 115
#
#               precision    recall  f1-score   support
#
#     negative       0.75      0.74      0.75      1848
#      neutral       0.21      0.46      0.29       692
#     positive       0.95      0.81      0.87      5253
#
#     accuracy                           0.76      7793
#    macro avg       0.64      0.67      0.64      7793
# weighted avg       0.84      0.76      0.79      7793

# %%
# Visualize the words that contribute most strongly
# to each sentiment class using Logistic Regression coefficients.
from src.visualization.nlp import plot_predictive_word
plot_predictive_word(model, vectorizer)
# Out:
# WordCloud module missing or failed. Try running: pip install wordcloud

# %% [markdown]
# The model achieved 76% overall accuracy, with strong recall for positive (81%) and negative (74%) reviews. However, performance on neutral reviews was poor (46%), likely due to the small sample size of just 692 instances.
#
# - **Negative:** delivery and transaction complaints — péss (terrible), receb (received), vei (came), pag (payment).
# - **Neutral:** mixed language — porém (however), demor (delay), razoá (reasonable) — customers acknowledging both sides.
# - **Positive:** praise for speed and quality — ant (early), excel (excellent), rápid (fast), recom (recommend).

# %% [markdown]
# ### 3.4 TF-IDF + Logistic Regression vs (XLM-RoBERTa (Portuguese fine-tuned))

# %%
# Load the pretrained Hugging Face sentiment baseline
from src.models.sentiment_comparison import compare_with_huggingface_baseline

# Compare TF-IDF sentiment labels with the pretrained model
report, match_rate = compare_with_huggingface_baseline(nlp_df)

# Display the classification performance
print(report)
# Out:
# ...
# 2026-08-09 04:45:16,575 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# 2026-08-09 04:45:38,179 src.models.sentiment_comparison INFO: HF baseline match rate vs TF-IDF labels: 66.6%
#               precision    recall  f1-score   support
#
#     negative       0.61      0.51      0.56       111
#      neutral       0.15      0.40      0.22        52
#     positive       0.95      0.76      0.84       337
#
#     accuracy                           0.67       500
#    macro avg       0.57      0.56      0.54       500
# weighted avg       0.79      0.67      0.71       500

# %% [markdown]
# - **Domain Knowledge:** Linear model significantly outperforms the deep learning transformer, achieving an overall accuracy of **76%** compared to the transformer's **67%**. This highlights that domain-specific training on e-commerce vocabulary yields superior results over generalized zero-shot models.
#
# - **The Neutral Challenge:** Both models encounter a performance bottleneck on the neutral class (F1-scores of `0.29` vs `0.22`). More samples are needed for improvement in recall rate.
#
# - **Efficiency & Latency:** The Logistic Regression model converged rapidly in just **116 iterations**, whereas the transformer required minutes for a 500-row sample.
#
# **Conclusion:** For this specific e-commerce task, a customized, lightweight pipeline delivers both higher predictive accuracy and production-level efficiency.
